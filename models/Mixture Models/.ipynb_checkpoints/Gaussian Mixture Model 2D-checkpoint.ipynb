# %%
using Distributions, LinearAlgebra, Plots, Random, LargeMessageCollider
Random.seed!(0);

# %%
# Generate Synthetic Data
N = 50 # number of data points

p1 = MvNormal([-10.0, 2.5], [1 0.5;0.5 0.4])
p2 = MvNormal([-3.0, -4.5], [0.25 0; 0 0.5])
p3 = MvNormal([7.5, 1.5], [1 0.2; 0.2 1.25])

real_mix = MixtureModel(MvNormal[p1,p2,p3], [0.5, 0.2, 0.3])

data = rand(real_mix, N);

# %%
X = range(-13, 10, length=200)
Y = range(-13, 10, length=200)
Z1 = [pdf(p1, [x,y]) for y in Y, x in X]
Z2 = [pdf(p2, [x,y]) for y in Y, x in X]
Z3 = [pdf(p3, [x,y]) for y in Y, x in X]
contour(X, Y, Z1)
contour!(X, Y, Z2)
contour!(X, Y, Z3)


scatter!(data[1,:], data[2,:], legend=false, color=:black)

# %%
# Priors
pm1, pm2, pm3 = MvNormal([-1,1],diagm(0=>10*ones(2))), MvNormal(3*ones(2),diagm(0=>10*ones(2))), MvNormal(-3*ones(2),diagm(0=>10*ones(2)))
pw1, pw2, pw3 = Wishart(2,diagm(0=>ones(2))), Wishart(2,diagm(0=>ones(2))), Wishart(2,diagm(0=>ones(2)))
pϕ = Dirichlet([0.1,0.1,0.1])
;

# %%
# Initial recognition factors
qm = [pm1, pm2, pm3]
qw = [pw1, pw2, pw3]
qϕ = pϕ
qz = Array{Categorical}(undef,N)
for n=1:N
    qz[n] = Categorical(3)
end
;

# %%
# Inference

for i=1:20
    # update qz
    for n=1:N
        vmp = normalmix(data[:,n],nothing,qm,qw)
        qz[n] = collide(categorical(nothing,qϕ),vmp)
    end

    # update qϕ
    vmp = categorical.(qz,nothing)
    qϕ = pϕ
    for n=1:N
        qϕ *= vmp[n]
    end

    # update qm
    qm = [pm1, pm2, pm3]
    for n=1:N
        vmp = normalmix(data[:,n],qz[n],nothing,qw)
        qm = collide.(qm, vmp)
    end

    # update qw
    qw = [pw1, pw2, pw3]
    for n=1:N
        vmp = normalmix(data[:,n],qz[n],qm,nothing)
        qw = collide.(qw, vmp)
    end
    
    # calculate Free Energy
    F = -entropy(qϕ) - sum(entropy.(qm)) - sum(entropy.(qw))
    F = F + cross_entropy(qϕ, pϕ) + sum(cross_entropy.(qm, [pm1, pm2, pm3])) + sum(cross_entropy.(qw, [pw1, pw2, pw3]))
    for n=1:N
        F -= entropy(qz[n])
        F += cross_entropy(qϕ, qz[n])
        F += normalmix(data[:,n],qz[n],qm,qw)
    end
    @show F
end
# Out:
# F = 242.4131536410542
# F = 233.57969413652512
# F = 225.98303818283384
# F = 216.16579736834336
# F = 206.25310074592576
# F = 193.06607454316273
# F = 187.13803124433792
# F = 186.62624175278057
# F = 186.6187929097696
# F = 186.61874360043967
# F = 186.61874330770485
# F = 186.6187433059811
# F = 186.6187433059686
# F = 186.61874330596856
# F = 186.6187433059715
# F = 186.61874330596834
# F = 186.61874330597163
# F = 186.61874330597115
# F = 186.61874330597055
# F = 186.6187433059693

# %%
qϕ
# Out:
# Dirichlet{Float64,Array{Float64,1},Float64}(alpha=[26.1, 13.1, 11.1])

# %%
qm
# Out:
# 3-element Array{MvNormal{Float64,PDMats.PDMat{Float64,Array{Float64,2}},Array{Float64,1}},1}:
#  FullNormal(
# dim: 2
# μ: [-9.854612526984718, 2.523801731383847]
# Σ: [0.03917464708436777 0.01665534821501281; 0.01665534821501281 0.01311487467914757]
# )
#
#  FullNormal(
# dim: 2
# μ: [7.309417117059386, 1.4120415738737726]
# Σ: [0.07756290301235258 -0.008230782632583472; -0.008230782632583472 0.037385819401659214]
# )
#
#  FullNormal(
# dim: 2
# μ: [-2.937487814466059, -4.204865186399124]
# Σ: [0.016542899616433137 0.004104631832309462; 0.004104631832309462 0.034051680749099894]
# )

# %%
qw
# Out:
# 3-element Array{Wishart{Float64,PDMats.PDMat{Float64,Array{Float64,2}},Int64},1}:
#  Wishart{Float64,PDMats.PDMat{Float64,Array{Float64,2}},Int64}(
# df: 28.0
# S: [0.07607764167791037 -0.0967899020871225; -0.0967899020871225 0.22751985633184346]
# )
#
#  Wishart{Float64,PDMats.PDMat{Float64,Array{Float64,2}},Int64}(
# df: 15.0
# S: [0.06718551407571995 0.014904321625259027; 0.014904321625259027 0.1399382768237197]
# )
#
#  Wishart{Float64,PDMats.PDMat{Float64,Array{Float64,2}},Int64}(
# df: 13.0
# S: [0.43505305113164344 -0.0525261289599142; -0.0525261289599142 0.21099678170786318]
# )

# %%
# Estimates
# We plot mixture distributions by using mean of approximate distributions

color_list = [:blue, :yellow, :red]
scatter((data[1,1],data[2,1]),color=color_list[argmax(qz[1].p)], legend=false)
for n=2:N
    scatter!((data[1,n],data[2,n]),color=color_list[argmax(qz[n].p)])
end
X = range(-13, 10, length=200)
Y = range(-13, 10, length=200)
Z1 = [pdf(MvNormal(mean(qm[1]),Matrix(Hermitian(inv(mean(qw[1]))))), [x,y]) for y in Y, x in X]
Z2 = [pdf(MvNormal(mean(qm[2]),Matrix(Hermitian(inv(mean(qw[2]))))), [x,y]) for y in Y, x in X]
Z3 = [pdf(MvNormal(mean(qm[3]),Matrix(Hermitian(inv(mean(qw[3]))))), [x,y]) for y in Y, x in X]
contour!(X, Y, Z1)
contour!(X, Y, Z2)
contour!(X, Y, Z3)
